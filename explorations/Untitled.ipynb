# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request

print('=3')
# Out:
# =3
# [nltk_data] Downloading package stopwords to /aiffel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### 데이터 준비하기

# %%
data = pd.read_csv(os.getenv("HOME")+"/aiffel/news_summarization/data/Reviews.csv", nrows=100000)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 100000

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
data = data[['Text','Summary']]
data.head()

#랜덤한 15개 샘플 출력
data.sample(15)
# Out:
#                                                     Text  \
# 36487  I was very apprehensive about the noodles, but...
# 91213  We all love this cereal and with 6 people in o...
# 5710   I've been looking for ground celery seed for a...
# 50019  Earth's Best Turkey Vegetable Dinner hits the ...
# 8877   I thought I didn't care for decaf espresso sin...
# 72465  Just what I wanted more or less and a good qua...
# 14470  As other reviewers noted, more than dozen of i...
# 73273  Amazon, Zappos and Nordstrom have the best cus...
# 25276  I grew up eating sourpower straws/belts as a c...
# 73226  **4.5  STARS**<br /><br />Really like these ch...
# 15498  I have a 2 1/2 year old black lab and these ar...
# 7192   Well, at least they live up to their name. The...
# 80922  Off and on over the years I've kept a package ...
# 67760  Tried many varieties of BBQ chips and hands do...
# 15494  I was intially introduced to Pro-Treat Beef Li...
#
#                                                  Summary
# 36487                                        DE-licious!
# 91213                                     a great cereal
# 5710                          have been searching for...
# 50019                      12% Protein and 50% Vitamin A
# 8877                    Turned me into an espresso lover
# 72465  Very crisp, two envelopes per package, and ver...
# 14470                                       Dissapointed
# 73273  Perfect, and customer service that was OUTSTAN...
# 25276                        Same great childhood taste.
# 73226                          Thin Chip BBQ Goodness...
# 15498                                    Best dog treats
# 7192                                                 Hot
# 80922                              Handy for "Seasoning"
# 67760                              BEST BUY in BBQ Chips
# 15494  Pro-Treat Beef Liver Freeze Dried, Best Part O...

# %% [markdown]
# ### 중복 샘플과 NULL 값이 존재하는 샘플 제거

# %%
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['Text'].nunique())
print('Summary 열에서 중복을 배제한 유일한 샘플의 수 :', data['Summary'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 88426
# Summary 열에서 중복을 배제한 유일한 샘플의 수 : 72348

# %%
# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['Text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88426

# %%
print(data.isnull().sum())
# Out:
# Text       0
# Summary    1
# dtype: int64

# %%
data.tail(5)
# Out:
#                                                     Text  \
# 99995  I just love it and will buy another box when I...
# 99996  My late father in law used to have a rating sy...
# 99997  This is my favorite brand of Korean ramen. It ...
# 99998  I do like these noodles although, to say they ...
# 99999  I love this noodle and have it once or twice a...
#
#                                                  Summary
# 99995                                             yummy!
# 99996                                  Tastes like More!
# 99997                                        Great ramen
# 99998                                            Spicy!!
# 99999  This spicy noodle cures my cold, upset stomach...

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
data.tail(5)
# Out:
# 전체 샘플수 : 88425
#                                                     Text  \
# 99995  I just love it and will buy another box when I...
# 99996  My late father in law used to have a rating sy...
# 99997  This is my favorite brand of Korean ramen. It ...
# 99998  I do like these noodles although, to say they ...
# 99999  I love this noodle and have it once or twice a...
#
#                                                  Summary
# 99995                                             yummy!
# 99996                                  Tastes like More!
# 99997                                        Great ramen
# 99998                                            Spicy!!
# 99999  This spicy noodle cures my cold, upset stomach...

# %% [markdown]
# ### 텍스트 정규화와 불용어 제거

# %%
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# #### 데이터 전처리 함수
# - 불용어 제거
#     - Summary와 같은 경우는 제외
# - 모든 영어 소문자
# - 섞여있는 html 태그 제거
# - 정규 표현식을 통해 각종 특수문자 제거

# %%
# 데이터 전처리 함수
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (Summary)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'

print(preprocess_sentence(temp_text))
print(preprocess_sentence(temp_summary, False))  # 불용어를 제거하지 않습니다.
# Out:
# everything bought great infact ordered twice third ordered wasfor mother father
# great way to start the day

# %% [markdown]
# + 생각해볼것
# wasfor이 한 단어로 합쳐지는 것이 의도된 것인가? 아니라면 수정하는 전처리 구문을 놓으면 좋겠다

# %% [markdown]
# ### 멀티프로세싱 사용

# %%
import multiprocessing as mp   # 멀티 프로세싱으로 전처리 속도를 획기적으로 줄여봅시다
from multiprocessing import Pool
import numpy as np
import time
from functools import partial  # map을 할 때 함수에 여러 인자를 넣어줄 수 있도록 합니다

start = time.time()

# num_cores 만큼 쪼개진 데이터를 전처리하여 반환합니다
def appendTexts(sentences, remove_stopwords):
  texts = []
  for s in sentences:
    texts += preprocess_sentence(s, remove_stopwords),
  return texts

def preprocess_data(data, remove_stopwords=True):
  start_time = time.time()
  num_cores = mp.cpu_count()  # 컴퓨터의 코어 수를 구합니다

  text_data_split = np.array_split(data, num_cores)  # 코어 수만큼 데이터를 배분하여 병렬적으로 처리할 수 있게 합니다
  pool = Pool(num_cores)

  processed_data = np.concatenate(pool.map(partial(appendTexts, remove_stopwords=remove_stopwords), text_data_split))  # 각자 작업한 데이터를 하나로 합쳐줍니다
  pool.close()
  pool.join()
  print(time.time() - start_time, " seconds")
  return processed_data

clean_text = preprocess_data(data['Text'])  # 클라우드 기준으로 3~4분 정도 소요 됩니다
print(clean_text)

clean_summary = preprocess_data(data['Summary'], remove_stopwords=False) # 클라우드 기준 1분정도 소요됩니다.
print(clean_summary)
# Out:
# 516.9137237071991  seconds
# ['bought several vitality canned dog food products found good quality product looks like stew processed meat smells better labrador finicky appreciates product better'
#  'product arrived labeled jumbo salted peanuts peanuts actually small sized unsalted sure error vendor intended represent product jumbo'
#  'confection around centuries light pillowy citrus gelatin nuts case filberts cut tiny squares liberally coated powdered sugar tiny mouthful heaven chewy flavorful highly recommend yummy treat familiar story lewis lion witch wardrobe treat seduces edmund selling brother sisters witch'
#  ...
#  'favorite brand korean ramen spicy used eating spicy food make sure use spice pack add egg soup makes great snack'
#  'like noodles although say spicy somewhat understatement one else family tolerates spicy well seeing looking forward extra little something palate disappointed completely honest usually drain liquid almost much'
#  'love noodle twice week amazing thing feel well cold hot bowl noodle cure upset stomach headache running nose may work definitely try']
# /opt/conda/lib/python3.7/site-packages/bs4/__init__.py:282: UserWarning: "http://www.amazon.com/gp/product/b007i7yygy/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# 11.432164430618286  seconds
# ['good quality dog food' 'not as advertised' 'delight says it all' ...
#  'great ramen' 'spicy'
#  'this spicy noodle cures my cold upset stomach and headache every time']

# %% [markdown]
# 시간이 남으면 멀티프로세싱 코드를 꼼꼼히 봐보자

# %%
data['Text'] = clean_text
data['Summary'] = clean_summary

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)

# %%
data.isnull().sum()
# Out:
# Text        0
# Summary    70
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 88355

# %% [markdown]
# ### 샘플 최대 길이 정하기

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(summary_len)
plt.title('Summary')
plt.subplot(1,2,2)
plt.boxplot(text_len)
plt.title('Text')
plt.tight_layout()
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 2
# 텍스트의 최대 길이 : 1235
# 텍스트의 평균 길이 : 38.792428272310566
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 28
# 요약의 평균 길이 : 4.010729443721352

# %%
text_max_len = 50
summary_max_len = 8

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['Text'])
below_threshold_len(summary_max_len,  data['Summary'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.7745119121724859
# 전체 샘플 중 길이가 8 이하인 샘플의 비율: 0.9424593967517402

# %% [markdown]
# 정해진 길이보다 길면 제외

# %%
data = data[data['Text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 65818

# %% [markdown]
# ### 시작 토큰과 종료 토큰 추가

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['Summary'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['Summary'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 Text                Summary  \
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanuts p...      not as advertised
# 2  confection around centuries light pillowy citr...    delight says it all
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wide assortment yummy ...            great taffy
#
#                     decoder_input                  decoder_target
# 0  sostoken good quality dog food  good quality dog food eostoken
# 1      sostoken not as advertised      not as advertised eostoken
# 2    sostoken delight says it all    delight says it all eostoken
# 3         sostoken cough medicine         cough medicine eostoken
# 4            sostoken great taffy            great taffy eostoken

# %%
encoder_input = np.array(data['Text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블

# %% [markdown]
# ### 훈련 데이터와 테스트 데이터 분리
#
# 직접 분리하자!! (분리 패키지 써도 됨)

# %%
# shape 길이만큼의 array를 만들고 순서 무작위로 섞기
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [53535   205 43797 ... 58146 24542 43005]

# %%
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]
# Out:
# [8 0 4 6 5 2 9 7 3 1]

# %%
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 13163

# %%
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 52655
# 훈련 레이블의 개수 : 52655
# 테스트 데이터의 개수 : 13163
# 테스트 레이블의 개수 : 13163

# %% [markdown]
# ### 단어 집합 만들기 및 정수 인코딩

# %%
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성

# %%
src_tokenizer.word_index
# Out:
# {'like': 1,
#  'good': 2,
#  'great': 3,
#  'taste': 4,
#  'product': 5,
#  'love': 6,
#  'one': 7,
#  'flavor': 8,
#  'coffee': 9,
#  'would': 10,
#  'tea': 11,
#  'really': 12,
#  'get': 13,
#  'amazon': 14,
#  'best': 15,
#  'buy': 16,
#  'price': 17,
#  'much': 18,
#  'food': 19,
#  'time': 20,
#  'little': 21,
#  'use': 22,
#  'find': 23,
#  'tried': 24,
#  'better': 25,
#  'chocolate': 26,
#  'also': 27,
#  'well': 28,
#  'make': 29,
#  'try': 30,
#  'eat': 31,
#  'dog': 32,
#  'even': 33,
#  'bought': 34,
#  'delicious': 35,
#  'sweet': 36,
#  'found': 37,
#  'drink': 38,
#  'could': 39,
#  'tastes': 40,
#  'order': 41,
#  'sugar': 42,
#  'recommend': 43,
#  'used': 44,
#  'loves': 45,
#  'favorite': 46,
#  'bag': 47,
#  'cannot': 48,
#  'cup': 49,
#  'first': 50,
#  'free': 51,
#  'made': 52,
#  'store': 53,
#  'nice': 54,
#  'way': 55,
#  'box': 56,
#  'go': 57,
#  'got': 58,
#  'perfect': 59,
#  'mix': 60,
#  'think': 61,
#  'day': 62,
#  'dogs': 63,
#  'bit': 64,
#  'treats': 65,
#  'since': 66,
#  'easy': 67,
#  'give': 68,
#  'hot': 69,
#  'flavors': 70,
#  'water': 71,
#  'ordered': 72,
#  'two': 73,
#  'many': 74,
#  'ever': 75,
#  'still': 76,
#  'never': 77,
#  'every': 78,
#  'snack': 79,
#  'makes': 80,
#  'stuff': 81,
#  'always': 82,
#  'without': 83,
#  'know': 84,
#  'right': 85,
#  'quality': 86,
#  'healthy': 87,
#  'brand': 88,
#  'want': 89,
#  'tasty': 90,
#  'years': 91,
#  'definitely': 92,
#  'strong': 93,
#  'buying': 94,
#  'hard': 95,
#  'treat': 96,
#  'lot': 97,
#  'fresh': 98,
#  'add': 99,
#  'keep': 100,
#  'enjoy': 101,
#  'something': 102,
#  'chips': 103,
#  'small': 104,
#  'old': 105,
#  'happy': 106,
#  'bad': 107,
#  'say': 108,
#  'excellent': 109,
#  'wonderful': 110,
#  'milk': 111,
#  'enough': 112,
#  'local': 113,
#  'highly': 114,
#  'organic': 115,
#  'less': 116,
#  'different': 117,
#  'salt': 118,
#  'shipping': 119,
#  'need': 120,
#  'purchase': 121,
#  'however': 122,
#  'eating': 123,
#  'regular': 124,
#  'size': 125,
#  'far': 126,
#  'sure': 127,
#  'looking': 128,
#  'tasting': 129,
#  'tasted': 130,
#  'products': 131,
#  'long': 132,
#  'thought': 133,
#  'put': 134,
#  'using': 135,
#  'back': 136,
#  'stores': 137,
#  'pretty': 138,
#  'whole': 139,
#  'though': 140,
#  'pack': 141,
#  'loved': 142,
#  'purchased': 143,
#  'cookies': 144,
#  'big': 145,
#  'bags': 146,
#  'texture': 147,
#  'work': 148,
#  'low': 149,
#  'worth': 150,
#  'high': 151,
#  'popcorn': 152,
#  'green': 153,
#  'package': 154,
#  'ingredients': 155,
#  'gluten': 156,
#  'quite': 157,
#  'arrived': 158,
#  'cat': 159,
#  'received': 160,
#  'thing': 161,
#  'family': 162,
#  'sauce': 163,
#  'grocery': 164,
#  'rice': 165,
#  'last': 166,
#  'cups': 167,
#  'bars': 168,
#  'take': 169,
#  'going': 170,
#  'calories': 171,
#  'year': 172,
#  'actually': 173,
#  'dark': 174,
#  'anything': 175,
#  'came': 176,
#  'real': 177,
#  'item': 178,
#  'natural': 179,
#  'expensive': 180,
#  'see': 181,
#  'feel': 182,
#  'cereal': 183,
#  'almost': 184,
#  'candy': 185,
#  'chicken': 186,
#  'husband': 187,
#  'butter': 188,
#  'another': 189,
#  'new': 190,
#  'oil': 191,
#  'full': 192,
#  'people': 193,
#  'smell': 194,
#  'trying': 195,
#  'morning': 196,
#  'disappointed': 197,
#  'absolutely': 198,
#  'money': 199,
#  'brands': 200,
#  'half': 201,
#  'getting': 202,
#  'several': 203,
#  'blend': 204,
#  'around': 205,
#  'kids': 206,
#  'fruit': 207,
#  'home': 208,
#  'bar': 209,
#  'amount': 210,
#  'coconut': 211,
#  'cats': 212,
#  'away': 213,
#  'added': 214,
#  'fat': 215,
#  'wish': 216,
#  'bitter': 217,
#  'diet': 218,
#  'fast': 219,
#  'available': 220,
#  'smooth': 221,
#  'light': 222,
#  'able': 223,
#  'flavored': 224,
#  'oz': 225,
#  'usually': 226,
#  'deal': 227,
#  'us': 228,
#  'dry': 229,
#  'black': 230,
#  'may': 231,
#  'come': 232,
#  'nothing': 233,
#  'per': 234,
#  'probably': 235,
#  'ones': 236,
#  'said': 237,
#  'liked': 238,
#  'bread': 239,
#  'problem': 240,
#  'breakfast': 241,
#  'days': 242,
#  'foods': 243,
#  'cheese': 244,
#  'company': 245,
#  'case': 246,
#  'ordering': 247,
#  'works': 248,
#  'things': 249,
#  'making': 250,
#  'seems': 251,
#  'boxes': 252,
#  'fine': 253,
#  'energy': 254,
#  'peanut': 255,
#  'cheaper': 256,
#  'juice': 257,
#  'quickly': 258,
#  'quick': 259,
#  'months': 260,
#  'gift': 261,
#  'protein': 262,
#  'reviews': 263,
#  'large': 264,
#  'save': 265,
#  'recommended': 266,
#  'glad': 267,
#  'especially': 268,
#  'rich': 269,
#  'kind': 270,
#  'gave': 271,
#  'teeth': 272,
#  'bottle': 273,
#  'drinking': 274,
#  'others': 275,
#  'cans': 276,
#  'instead': 277,
#  'variety': 278,
#  'look': 279,
#  'white': 280,
#  'syrup': 281,
#  'honey': 282,
#  'anyone': 283,
#  'house': 284,
#  'prefer': 285,
#  'son': 286,
#  'spicy': 287,
#  'packaging': 288,
#  'three': 289,
#  'comes': 290,
#  'top': 291,
#  'cream': 292,
#  'amazing': 293,
#  'soft': 294,
#  'maybe': 295,
#  'fan': 296,
#  'everyone': 297,
#  'vanilla': 298,
#  'thank': 299,
#  'might': 300,
#  'yummy': 301,
#  'times': 302,
#  'likes': 303,
#  'thanks': 304,
#  'seem': 305,
#  'wanted': 306,
#  'must': 307,
#  'either': 308,
#  'nuts': 309,
#  'teas': 310,
#  'next': 311,
#  'fact': 312,
#  'roast': 313,
#  'salty': 314,
#  'ginger': 315,
#  'extra': 316,
#  'value': 317,
#  'enjoyed': 318,
#  'stars': 319,
#  'month': 320,
#  'plus': 321,
#  'else': 322,
#  'daughter': 323,
#  'awesome': 324,
#  'everything': 325,
#  'pieces': 326,
#  'friends': 327,
#  'longer': 328,
#  'ago': 329,
#  'yet': 330,
#  'super': 331,
#  'couple': 332,
#  'beans': 333,
#  'cost': 334,
#  'health': 335,
#  'pasta': 336,
#  'crunchy': 337,
#  'least': 338,
#  'baby': 339,
#  'bold': 340,
#  'went': 341,
#  'meal': 342,
#  'ice': 343,
#  'market': 344,
#  'online': 345,
#  'cocoa': 346,
#  'open': 347,
#  'help': 348,
#  'mouth': 349,
#  'started': 350,
#  'ok': 351,
#  'pepper': 352,
#  'keurig': 353,
#  'pleased': 354,
#  'decided': 355,
#  'cold': 356,
#  'expected': 357,
#  'says': 358,
#  'took': 359,
#  'cookie': 360,
#  'jerky': 361,
#  'snacks': 362,
#  'although': 363,
#  'alternative': 364,
#  'lemon': 365,
#  'week': 366,
#  'minutes': 367,
#  'machine': 368,
#  'drinks': 369,
#  'review': 370,
#  'soda': 371,
#  'weight': 372,
#  'service': 373,
#  'decaf': 374,
#  'soup': 375,
#  'chew': 376,
#  'flavorful': 377,
#  'rather': 378,
#  'crackers': 379,
#  'corn': 380,
#  'let': 381,
#  'powder': 382,
#  'delivery': 383,
#  'second': 384,
#  'wife': 385,
#  'wheat': 386,
#  'noodles': 387,
#  'read': 388,
#  'goes': 389,
#  'exactly': 390,
#  'ounce': 391,
#  'surprised': 392,
#  'mixed': 393,
#  'plain': 394,
#  'version': 395,
#  'easily': 396,
#  'gets': 397,
#  'aroma': 398,
#  'clean': 399,
#  'beef': 400,
#  'smaller': 401,
#  'opened': 402,
#  'believe': 403,
#  'type': 404,
#  'cooking': 405,
#  'sometimes': 406,
#  'convenient': 407,
#  'aftertaste': 408,
#  'fantastic': 409,
#  'cook': 410,
#  'shipped': 411,
#  'almonds': 412,
#  'cinnamon': 413,
#  'meat': 414,
#  'special': 415,
#  'part': 416,
#  'smells': 417,
#  'cake': 418,
#  'pop': 419,
#  'problems': 420,
#  'place': 421,
#  'oatmeal': 422,
#  'packaged': 423,
#  'choice': 424,
#  'hand': 425,
#  'side': 426,
#  'friend': 427,
#  'artificial': 428,
#  'plastic': 429,
#  'reason': 430,
#  'orange': 431,
#  'guess': 432,
#  'serving': 433,
#  'wrong': 434,
#  'difference': 435,
#  'care': 436,
#  'picky': 437,
#  'tell': 438,
#  'mild': 439,
#  'packs': 440,
#  'red': 441,
#  'dried': 442,
#  'left': 443,
#  'giving': 444,
#  'slightly': 445,
#  'refreshing': 446,
#  'potato': 447,
#  'iced': 448,
#  'brown': 449,
#  'christmas': 450,
#  'recipe': 451,
#  'stomach': 452,
#  'coffees': 453,
#  'huge': 454,
#  'continue': 455,
#  'line': 456,
#  'cut': 457,
#  'bite': 458,
#  'bulk': 459,
#  'spice': 460,
#  'cherry': 461,
#  'recently': 462,
#  'subscribe': 463,
#  'chewy': 464,
#  'live': 465,
#  'french': 466,
#  'starbucks': 467,
#  'etc': 468,
#  'often': 469,
#  'run': 470,
#  'lots': 471,
#  'brew': 472,
#  'chai': 473,
#  'filling': 474,
#  'needed': 475,
#  'gives': 476,
#  'looks': 477,
#  'seeds': 478,
#  'sent': 479,
#  'night': 480,
#  'delivered': 481,
#  'fiber': 482,
#  'life': 483,
#  'pay': 484,
#  'excited': 485,
#  'compared': 486,
#  'end': 487,
#  'stick': 488,
#  'container': 489,
#  'close': 490,
#  'unfortunately': 491,
#  'original': 492,
#  'looked': 493,
#  'simply': 494,
#  'start': 495,
#  'bottles': 496,
#  'calorie': 497,
#  'carry': 498,
#  'overall': 499,
#  'toy': 500,
#  'chip': 501,
#  'larger': 502,
#  'canned': 503,
#  'ate': 504,
#  'com': 505,
#  'eaten': 506,
#  'nut': 507,
#  'needs': 508,
#  'past': 509,
#  'packages': 510,
#  'broken': 511,
#  'gum': 512,
#  'lunch': 513,
#  'date': 514,
#  'granola': 515,
#  'microwave': 516,
#  'apple': 517,
#  'someone': 518,
#  'creamy': 519,
#  'soon': 520,
#  'seller': 521,
#  'wait': 522,
#  'healthier': 523,
#  'weak': 524,
#  'items': 525,
#  'extremely': 526,
#  'heat': 527,
#  'caffeine': 528,
#  'sweetness': 529,
#  'helps': 530,
#  'espresso': 531,
#  'color': 532,
#  'keeps': 533,
#  'finally': 534,
#  'baking': 535,
#  'hair': 536,
#  'weeks': 537,
#  'purchasing': 538,
#  'crunch': 539,
#  'dinner': 540,
#  'greenies': 541,
#  'idea': 542,
#  'seasoning': 543,
#  'gone': 544,
#  'similar': 545,
#  'saw': 546,
#  'stock': 547,
#  'hope': 548,
#  'fish': 549,
#  'condition': 550,
#  'sold': 551,
#  'takes': 552,
#  'daily': 553,
#  'pumpkin': 554,
#  'inside': 555,
#  'packed': 556,
#  'waste': 557,
#  'already': 558,
#  'jar': 559,
#  'four': 560,
#  'banana': 561,
#  'change': 562,
#  'stale': 563,
#  'along': 564,
#  'star': 565,
#  'course': 566,
#  'single': 567,
#  'experience': 568,
#  'training': 569,
#  'consistency': 570,
#  'feed': 571,
#  'flour': 572,
#  'given': 573,
#  'salad': 574,
#  'soy': 575,
#  'pound': 576,
#  'licorice': 577,
#  'non': 578,
#  'pork': 579,
#  'difficult': 580,
#  'locally': 581,
#  'medium': 582,
#  'chews': 583,
#  'shipment': 584,
#  'please': 585,
#  'hooked': 586,
#  'expect': 587,
#  'hours': 588,
#  'mine': 589,
#  'name': 590,
#  'anywhere': 591,
#  'pet': 592,
#  'cheap': 593,
#  'hit': 594,
#  'vet': 595,
#  'instant': 596,
#  'leave': 597,
#  'adding': 598,
#  'together': 599,
#  'done': 600,
#  'formula': 601,
#  'moist': 602,
#  'puppy': 603,
#  'rest': 604,
#  'satisfying': 605,
#  'reasonable': 606,
#  'maker': 607,
#  'crazy': 608,
#  'thick': 609,
#  'beat': 610,
#  'leaves': 611,
#  'packets': 612,
#  'newman': 613,
#  'due': 614,
#  'olive': 615,
#  'completely': 616,
#  'list': 617,
#  'easier': 618,
#  'raw': 619,
#  'stopped': 620,
#  'stop': 621,
#  'certainly': 622,
#  'substitute': 623,
#  'fun': 624,
#  'baked': 625,
#  'within': 626,
#  'future': 627,
#  'lb': 628,
#  'ground': 629,
#  'based': 630,
#  'break': 631,
#  'shop': 632,
#  'combination': 633,
#  'totally': 634,
#  'kick': 635,
#  'pure': 636,
#  'decent': 637,
#  'area': 638,
#  'pot': 639,
#  'chili': 640,
#  'ingredient': 641,
#  'anymore': 642,
#  'pancakes': 643,
#  'sodium': 644,
#  'maple': 645,
#  'okay': 646,
#  'worked': 647,
#  'opinion': 648,
#  'recipes': 649,
#  'yogurt': 650,
#  'bland': 651,
#  'wow': 652,
#  'finding': 653,
#  'throw': 654,
#  'hour': 655,
#  'eats': 656,
#  'stay': 657,
#  'hint': 658,
#  'grey': 659,
#  'yum': 660,
#  'pick': 661,
#  'bowl': 662,
#  'true': 663,
#  'satisfied': 664,
#  'entire': 665,
#  'mind': 666,
#  'pricey': 667,
#  'addition': 668,
#  'simple': 669,
#  'spices': 670,
#  'yes': 671,
#  'sour': 672,
#  'sale': 673,
#  'today': 674,
#  'almond': 675,
#  'perfectly': 676,
#  'batch': 677,
#  'carb': 678,
#  'mint': 679,
#  'horrible': 680,
#  'mixes': 681,
#  'switch': 682,
#  'grain': 683,
#  'five': 684,
#  'summer': 685,
#  'packet': 686,
#  'none': 687,
#  'favorites': 688,
#  'content': 689,
#  'twice': 690,
#  'become': 691,
#  'piece': 692,
#  'option': 693,
#  'sell': 694,
#  'six': 695,
#  'truly': 696,
#  'seemed': 697,
#  'pleasant': 698,
#  'finish': 699,
#  'mess': 700,
#  'awful': 701,
#  'plan': 702,
#  'discovered': 703,
#  'count': 704,
#  'contains': 705,
#  'world': 706,
#  'terrible': 707,
#  'cooked': 708,
#  'priced': 709,
#  'remember': 710,
#  'later': 711,
#  'pie': 712,
#  'expecting': 713,
#  'mountain': 714,
#  'acid': 715,
#  'roasted': 716,
#  'dish': 717,
#  'hoping': 718,
#  'forward': 719,
#  'sweetener': 720,
#  'salmon': 721,
#  'particular': 722,
#  'told': 723,
#  'dont': 724,
#  'tiny': 725,
#  'normally': 726,
#  'earl': 727,
#  'varieties': 728,
#  'drinker': 729,
#  'loose': 730,
#  'warm': 731,
#  'return': 732,
#  'door': 733,
#  'customer': 734,
#  'thin': 735,
#  'lower': 736,
#  'noticed': 737,
#  'shake': 738,
#  'unlike': 739,
#  'prices': 740,
#  'strawberry': 741,
#  'vinegar': 742,
#  'bones': 743,
#  'paid': 744,
#  'contain': 745,
#  'label': 746,
#  'otherwise': 747,
#  'issues': 748,
#  'glass': 749,
#  'ready': 750,
#  'breath': 751,
#  'costco': 752,
#  'mom': 753,
#  'everyday': 754,
#  'supermarket': 755,
#  'chocolates': 756,
#  'blue': 757,
#  'normal': 758,
#  'bottom': 759,
#  'anyway': 760,
#  'bears': 761,
#  'skin': 762,
#  'felt': 763,
#  'unless': 764,
#  'impressed': 765,
#  'beverage': 766,
#  'serve': 767,
#  'called': 768,
#  'body': 769,
#  'seen': 770,
#  'garlic': 771,
#  'oh': 772,
#  'bring': 773,
#  'description': 774,
#  'adds': 775,
#  'caramel': 776,
#  'overly': 777,
#  'turned': 778,
#  'office': 779,
#  'convenience': 780,
#  'italian': 781,
#  'shape': 782,
#  'agree': 783,
#  'job': 784,
#  'overpowering': 785,
#  'ask': 786,
#  'bake': 787,
#  'except': 788,
#  'individual': 789,
#  'bean': 790,
#  'homemade': 791,
#  'ship': 792,
#  'immediately': 793,
#  'thinking': 794,
#  'liquid': 795,
#  'touch': 796,
#  'china': 797,
#  'feeling': 798,
#  'point': 799,
#  'subscription': 800,
#  'raspberry': 801,
#  'stronger': 802,
#  'meals': 803,
#  'candies': 804,
#  'set': 805,
#  'carbs': 806,
#  'allergies': 807,
#  'thrilled': 808,
#  'peanuts': 809,
#  'carrying': 810,
#  'flavoring': 811,
#  'complaint': 812,
#  'results': 813,
#  'sick': 814,
#  'sea': 815,
#  'nicely': 816,
#  'party': 817,
#  'balance': 818,
#  'matter': 819,
#  'afternoon': 820,
#  'dented': 821,
#  'uses': 822,
#  'changed': 823,
#  'benefits': 824,
#  'bbq': 825,
#  'hands': 826,
#  'check': 827,
#  'person': 828,
#  'biscuits': 829,
#  'wrapped': 830,
#  'plenty': 831,
#  'nearly': 832,
#  'stevia': 833,
#  'kitchen': 834,
#  'chewing': 835,
#  'somewhat': 836,
#  'fit': 837,
#  'jelly': 838,
#  'supposed': 839,
#  'craving': 840,
#  'pops': 841,
#  'pizza': 842,
#  'lover': 843,
#  'heavy': 844,
#  'reading': 845,
#  'mostly': 846,
#  'crisp': 847,
#  'weird': 848,
#  'addicted': 849,
#  'berry': 850,
#  'plant': 851,
#  'lime': 852,
#  'served': 853,
#  'feeding': 854,
#  'kept': 855,
#  'taking': 856,
#  'fairly': 857,
#  'kid': 858,
#  'brought': 859,
#  'short': 860,
#  'veggies': 861,
#  'cashews': 862,
#  'sample': 863,
#  'share': 864,
#  'trouble': 865,
#  'grams': 866,
#  'worst': 867,
#  'bigger': 868,
#  'gf': 869,
#  'nutrition': 870,
#  'walmart': 871,
#  'send': 872,
#  'sauces': 873,
#  'hate': 874,
#  'brewed': 875,
#  'lbs': 876,
#  'usual': 877,
#  'replacement': 878,
#  'coming': 879,
#  'call': 880,
#  'brownies': 881,
#  'types': 882,
#  'reviewers': 883,
#  'pods': 884,
#  'carbonated': 885,
#  'mother': 886,
#  'prepare': 887,
#  'expiration': 888,
#  'higher': 889,
#  'double': 890,
#  'kinds': 891,
#  'style': 892,
#  'gourmet': 893,
#  'eggs': 894,
#  'picture': 895,
#  'bitterness': 896,
#  'source': 897,
#  'pour': 898,
#  'sorry': 899,
#  'fill': 900,
#  'boost': 901,
#  'covered': 902,
#  'portion': 903,
#  'pleasantly': 904,
#  'near': 905,
#  'enjoys': 906,
#  'stuck': 907,
#  'ended': 908,
#  'tuna': 909,
#  'cause': 910,
#  'alot': 911,
#  'perhaps': 912,
#  'running': 913,
#  'quantity': 914,
#  'sticks': 915,
#  'directions': 916,
#  'crispy': 917,
#  'sitting': 918,
#  'means': 919,
#  'notice': 920,
#  'hazelnut': 921,
#  'dessert': 922,
#  'birthday': 923,
#  'busy': 924,
#  'wine': 925,
#  'disappointing': 926,
#  'stash': 927,
#  'reviewer': 928,
#  'working': 929,
#  'whatever': 930,
#  'heard': 931,
#  'sealed': 932,
#  'alone': 933,
#  'potatoes': 934,
#  'paying': 935,
#  'threw': 936,
#  'jars': 937,
#  'clear': 938,
#  'sweetened': 939,
#  'tart': 940,
#  'children': 941,
#  'brewing': 942,
#  'lab': 943,
#  'issue': 944,
#  'pounds': 945,
#  'unique': 946,
#  'careful': 947,
#  'mustard': 948,
#  'cheddar': 949,
#  'fair': 950,
#  'gummy': 951,
#  'outside': 952,
#  'selling': 953,
#  'chance': 954,
#  'website': 955,
#  'sensitive': 956,
#  'whenever': 957,
#  'sort': 958,
#  'dishes': 959,
#  'school': 960,
#  'gotten': 961,
#  'number': 962,
#  'usa': 963,
#  'nasty': 964,
#  'helped': 965,
#  'blood': 966,
#  'standard': 967,
#  'beer': 968,
#  'shelf': 969,
#  'blends': 970,
#  'knew': 971,
#  'vegan': 972,
#  'supply': 973,
#  'putting': 974,
#  'restaurant': 975,
#  'wants': 976,
#  'beautiful': 977,
#  'soups': 978,
#  'instructions': 979,
#  'lost': 980,
#  'vegetables': 981,
#  'personally': 982,
#  'site': 983,
#  'grade': 984,
#  'zico': 985,
#  'subtle': 986,
#  'dairy': 987,
#  'dressing': 988,
#  'gummi': 989,
#  'fridge': 990,
#  'trip': 991,
#  'english': 992,
#  'surprise': 993,
#  'slight': 994,
#  'fabulous': 995,
#  'mini': 996,
#  'consider': 997,
#  'sized': 998,
#  'turn': 999,
#  'straight': 1000,
#  ...}

# %%
src_tokenizer.word_index.items(5)
