# %% [markdown]
# PIL 이용하여 이미지 생성해보기

# %%
import numpy as np
from PIL import Image

data = np.zeros([32, 32, 3], dtype=np.uint8)
image = Image.fromarray(data, 'RGB')
image
# Out:
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FE9D7EB4D50>

# %%
data[:, :] = [255, 0, 0]
image = Image.fromarray(data, 'RGB')
image
# Out:
# <class 'numpy.ndarray'>
# <PIL.Image.Image image mode=RGB size=32x32 at 0x7FE9D687DA10>

# %% [markdown]
# 연습용 이미지 파일 가공

# %%
import os

# %%
image_path = os.getenv('HOME')+'/aiffel/python_image_prac/data/pillow_practice.png'
image = Image.open(image_path)

# %%
print(image.width, image.height)
# Out:
# 620 465

# %%
new_img_path = os.getenv('HOME')+'/aiffel/python_image_prac/data/jpg_pillow_practice.jpg'

image = image.convert('RGB')
image.save(new_img_path)

# %% [markdown]
# resize() 이용하여 100X200으로 변경

# %%
resized_img = image.resize((100, 200))
print(resized_img.width, resized_img.height)
resized_img
# Out:
# 100 200
# <PIL.Image.Image image mode=RGB size=100x200 at 0x7FE9D5CF6990>

# %% [markdown]
# 눈 부분만 잘라내어 저장

# %%
img = image
box = (300, 100, 600, 400)
region = img.crop(box)
region
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FE9D5D06B50>

# %%
a = {'abc':1}
type(a)
# Out:
# dict

# %%
b = list(a.keys())
b
# Out:
# ['abc']
