# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
print('슝=3')
# Out:
# 슝=3

# %%
import os
csv_path = os.getenv("HOME") +"/aiffel/pokemon_eda/data/Pokemon.csv"
original_data = pd.read_csv(csv_path)
print('슝=3')
# Out:
# 슝=3

# %%
pokemon = original_data.copy()
pokemon_cp = original_data.copy()

# %%
legendary = pokemon[pokemon["Legendary"] == True].reset_index()
print(legendary.shape)
legendary.head()
# Out:
# (65, 14)
#    index    #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 0    156  144             Articuno       Ice    Flying    580   90      85
# 1    157  145               Zapdos  Electric    Flying    580   90      90
# 2    158  146              Moltres      Fire    Flying    580   90     100
# 3    162  150               Mewtwo   Psychic       NaN    680  106     110
# 4    163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0      100       95      125     85           1       True
# 1       85      125       90    100           1       True
# 2       90      125       85     90           1       True
# 3       90      154       90    130           1       True
# 4      100      154      100    130           1       True

# %%
legendary = pokemon[pokemon["Legendary"] == True].reset_index(drop=True)
print(legendary.shape)
legendary.head()
# Out:
# (65, 13)
#      #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0  144             Articuno       Ice    Flying    580   90      85      100
# 1  145               Zapdos  Electric    Flying    580   90      90       85
# 2  146              Moltres      Fire    Flying    580   90     100       90
# 3  150               Mewtwo   Psychic       NaN    680  106     110       90
# 4  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       95      125     85           1       True
# 1      125       90    100           1       True
# 2      125       85     90           1       True
# 3      154       90    130           1       True
# 4      154      100    130           1       True

# %%
len(list(set(pokemon["Type 1"]))), len(list(set(pokemon["Type 2"])))
# Out:
# (18, 19)

# %%
len(set(pokemon["Type 1"])), len(set(pokemon["Type 2"]))
# Out:
# (18, 19)

# %%
types = set(pokemon["Type 1"])
print(len(types))
print(types)
# Out:
# 18
# {'Bug', 'Electric', 'Dragon', 'Fairy', 'Ice', 'Rock', 'Fire', 'Dark', 'Psychic', 'Water', 'Flying', 'Poison', 'Steel', 'Normal', 'Ground', 'Ghost', 'Fighting', 'Grass'}

# %%
legendary = pokemon[pokemon["Legendary"] == True].reset_index(drop=True)
ordinary = pokemon[pokemon["Legendary"] == False].reset_index(drop=True)

# %%
plt.figure(figsize=(10, 7))  # 화면 해상도에 따라 그래프 크기를 조정해 주세요.

plt.subplot(211)
sns.countplot(data=ordinary, x="Type 1").set_xlabel('')
plt.title("[Ordinary Pokemons]")

plt.subplot(212)
sns.countplot(data=legendary, x="Type 1", order=types).set_xlabel('')
plt.title("[Legendary Pokemons]")

plt.show()

# %%
pd.pivot_table(pokemon, index="Type 2", values="Legendary").sort_values(by=["Legendary"], ascending=False)
# Out:
#           Legendary
# Type 2
# Fire       0.250000
# Dragon     0.222222
# Ice        0.214286
# Electric   0.166667
# Fighting   0.153846
# Psychic    0.151515
# Flying     0.134021
# Fairy      0.086957
# Water      0.071429
# Ghost      0.071429
# Dark       0.050000
# Steel      0.045455
# Ground     0.028571
# Rock       0.000000
# Bug        0.000000
# Poison     0.000000
# Normal     0.000000
# Grass      0.000000

# %%
stats = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]

# %%
sum(pokemon['Total'].values == pokemon[stats].values.sum(axis=1))
# Out:
# 800

# %%
pokemon[stats].values
# Out:
# 800

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 6)  # 화면 해상도에 따라 그래프 크기를 조정해 주세요.

#sns.scatterplot(data=pokemon, x="Type 1", y="Total", hue="Legendary")
sns.scatterplot(data=pokemon, x="Type 1", y="Total")
plt.show()

# %%
figure, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(nrows=3, ncols=2)
figure.set_size_inches(12, 18)  # 화면 해상도에 따라 그래프 크기를 조정해 주세요.

sns.scatterplot(data=pokemon, y="Total", x="HP", hue="Legendary", ax=ax1)
sns.scatterplot(data=pokemon, y="Total", x="Attack", hue="Legendary", ax=ax2)
sns.scatterplot(data=pokemon, y="Total", x="Defense", hue="Legendary", ax=ax3)
sns.scatterplot(data=pokemon, y="Total", x="Sp. Atk", hue="Legendary", ax=ax4)
sns.scatterplot(data=pokemon, y="Total", x="Sp. Def", hue="Legendary", ax=ax5)
sns.scatterplot(data=pokemon, y="Total", x="Speed", hue="Legendary", ax=ax6)
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 4)

sns.scatterplot(y="Type 1", x="Total")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-3bbbba96ed7c> in <module>
#       2 fig.set_size_inches(8, 4)
#       3
# ----> 4 sns.scatterplot(y="Type 1", x="Total")
#       5 plt.show()
#
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/conda/lib/python3.7/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     803         x_bins=x_bins, y_bins=y_bins,
#     804         estimator=estimator, ci=ci, n_boot=n_boot,
# ...

# %%
round(3.14)
# Out:
# 3

# %%
round(3.5)
# Out:
# 4

# %%
round(3.4)
# Out:
# 3

# %%
round(4.5)
# Out:
# 4

# %%
round(4.6)
# Out:
# 5

# %%
round(4.51)
# Out:
# 5

# %%
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary        Name_nospace
# 795      100      150     50           6       True             Diancie
# 796      160      110    110           6       True  DiancieMegaDiancie
# 797      150      130     70           6       True  HoopaHoopaConfined
# 798      170      130     80           6       True   HoopaHoopaUnbound
# 799      130       90     70           6       True           Volcanion

# %%
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha())
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary          Name_nospace  \
# 0       65       65     45           1      False             Bulbasaur
# 1       80       80     60           1      False               Ivysaur
# 2      100      100     80           1      False              Venusaur
# 3      122      120     80           1      False  VenusaurMegaVenusaur
# 4       60       50     65           1      False            Charmander
#
#    name_isalpha
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
