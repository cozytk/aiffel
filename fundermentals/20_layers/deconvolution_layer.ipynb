# %%
import numpy as np
from tensorflow.python.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.datasets import mnist
import json
import matplotlib.pyplot as plt #for plotting

# MNIST 데이터 로딩
(x_train, _), (x_test, _) = mnist.load_data()    # y_train, y_test는 사용하지 않습니다.

x_train = np.expand_dims(x_train, axis=3)
x_test = np.expand_dims(x_test, axis=3)

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
# AutoEncoder 모델 구성 - Input 부분
input_shape = x_train.shape[1:]
input_img = Input(shape=input_shape)

# AutoEncoder 모델 구성 - Encoder 부분
encode_conv_layer_1 = Conv2D(16, (3, 3), activation='relu', padding='same')
encode_pool_layer_1 = MaxPooling2D((2, 2), padding='same')
encode_conv_layer_2 = Conv2D(8, (3, 3), activation='relu', padding='same')
encode_pool_layer_2 = MaxPooling2D((2, 2), padding='same')
encode_conv_layer_3 = Conv2D(4, (3, 3), activation='relu', padding='same')
encode_pool_layer_3 = MaxPooling2D((2, 2), padding='same')

encoded = encode_conv_layer_1(input_img)
encoded = encode_pool_layer_1(encoded)
encoded = encode_conv_layer_2(encoded)
encoded = encode_pool_layer_2(encoded)
encoded = encode_conv_layer_3(encoded)
encoded = encode_pool_layer_3(encoded)

# AutoEncoder 모델 구성 - Decoder 부분
decode_conv_layer_1 = Conv2D(4, (3, 3), activation='relu', padding='same')
decode_upsample_layer_1 = UpSampling2D((2, 2))
decode_conv_layer_2 = Conv2D(8, (3, 3), activation='relu', padding='same')
decode_upsample_layer_2 = UpSampling2D((2, 2))
decode_conv_layer_3 = Conv2D(16, (3, 3), activation='relu')
decode_upsample_layer_3 = UpSampling2D((2, 2))
decode_conv_layer_4 = Conv2D(1, (3, 3), activation='sigmoid', padding='same')

decoded = decode_conv_layer_1(encoded)   # Decoder는 Encoder의 출력을 입력으로 받습니다.
decoded = decode_upsample_layer_1(decoded)
decoded = decode_conv_layer_2(decoded)
decoded = decode_upsample_layer_2(decoded)
decoded = decode_conv_layer_3(decoded)
decoded = decode_upsample_layer_3(decoded)
decoded = decode_conv_layer_4(decoded)

# AutoEncoder 모델 정의
autoencoder = Model(input_img, decoded)
autoencoder.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 7, 7, 4)           292
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 4)           0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 4)           148
# _________________________________________________________________
# up_sampling2d_12 (UpSampling (None, 8, 8, 4)           0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 8, 8, 8)           296
# _________________________________________________________________
# up_sampling2d_13 (UpSampling (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_14 (UpSampling (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 28, 28, 1)         145
# =================================================================
# Total params: 3,369
# Trainable params: 3,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.6938 - val_loss: 0.6928
# Epoch 2/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6923 - val_loss: 0.6911
# Epoch 3/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6905 - val_loss: 0.6889
# Epoch 4/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6882 - val_loss: 0.6857
# Epoch 5/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6845 - val_loss: 0.6803
# Epoch 6/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6780 - val_loss: 0.6698
# Epoch 7/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6651 - val_loss: 0.6473
# Epoch 8/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.6370 - val_loss: 0.5986
# Epoch 9/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.5796 - val_loss: 0.5286
# Epoch 10/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.5154 - val_loss: 0.5009
# Epoch 11/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4956 - val_loss: 0.4941
# Epoch 12/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4890 - val_loss: 0.4889
# Epoch 13/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4835 - val_loss: 0.4839
# Epoch 14/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4795 - val_loss: 0.4789
# Epoch 15/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4741 - val_loss: 0.4740
# Epoch 16/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4691 - val_loss: 0.4691
# Epoch 17/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4644 - val_loss: 0.4642
# Epoch 18/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4593 - val_loss: 0.4594
# Epoch 19/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4542 - val_loss: 0.4547
# Epoch 20/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4497 - val_loss: 0.4500
# Epoch 21/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4457 - val_loss: 0.4455
# Epoch 22/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4413 - val_loss: 0.4408
# Epoch 23/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4361 - val_loss: 0.4356
# Epoch 24/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4304 - val_loss: 0.4299
# Epoch 25/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4262 - val_loss: 0.4235
# Epoch 26/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4192 - val_loss: 0.4160
# Epoch 27/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.4110 - val_loss: 0.4072
# Epoch 28/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4022 - val_loss: 0.3972
# Epoch 29/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3921 - val_loss: 0.3866
# Epoch 30/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3822 - val_loss: 0.3767
# Epoch 31/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3716 - val_loss: 0.3675
# Epoch 32/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3631 - val_loss: 0.3590
# Epoch 33/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3547 - val_loss: 0.3509
# Epoch 34/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3471 - val_loss: 0.3431
# Epoch 35/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3393 - val_loss: 0.3355
# Epoch 36/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3326 - val_loss: 0.3285
# Epoch 37/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3257 - val_loss: 0.3219
# Epoch 38/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3186 - val_loss: 0.3159
# Epoch 39/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3127 - val_loss: 0.3104
# Epoch 40/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3077 - val_loss: 0.3053
# Epoch 41/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.3029 - val_loss: 0.3008
# Epoch 42/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2989 - val_loss: 0.2966
# Epoch 43/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.2939 - val_loss: 0.2927
# Epoch 44/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.2903 - val_loss: 0.2892
# Epoch 45/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2873 - val_loss: 0.2859
# Epoch 46/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2838 - val_loss: 0.2829
# Epoch 47/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2811 - val_loss: 0.2801
# Epoch 48/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2782 - val_loss: 0.2775
# Epoch 49/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2759 - val_loss: 0.2751
# Epoch 50/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.2735 - val_loss: 0.2728

# %%
x_test_10 = x_test[:10]       # 테스트 데이터셋에서 10개만 골라서
x_test_hat = autoencoder.predict(x_test_10)    # AutoEncoder 모델의 이미지 복원생성
x_test_imgs = x_test_10.reshape(-1, 28, 28)
x_test_hat_imgs = x_test_hat.reshape(-1, 28, 28)

plt.figure(figsize=(12,5))  # 이미지 사이즈 지정
for i in range(10):
    # 원본이미지 출력
    plt.subplot(2, 10, i+1)
    plt.imshow(x_test_imgs[i])
    # 생성된 이미지 출력
    plt.subplot(2, 10, i+11)
    plt.imshow(x_test_hat_imgs[i])

# %%
import numpy as np
from tensorflow.python.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.python.keras.models import Model
from tensorflow.python.keras.datasets import mnist
import json
import matplotlib.pyplot as plt #for plotting

# MNIST 데이터 로딩
(x_train, _), (x_test, _) = mnist.load_data()    # y_train, y_test는 사용하지 않습니다.

x_train = np.expand_dims(x_train, axis=3)
x_test = np.expand_dims(x_test, axis=3)

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# %%
from tensorflow.python.keras.layers import Conv2DTranspose

# Conv2DTranspose를 활용한  AutoEncoder 모델
# AutoEncoder 모델 구성 - Input 부분
input_shape = x_train.shape[1:]
input_img = Input(shape=input_shape)

# AutoEncoder 모델 구성 - Encoder 부분
encode_conv_layer_1 = Conv2D(16, (3, 3), activation='relu')
encode_pool_layer_1 = MaxPooling2D((2, 2))
encode_conv_layer_2 = Conv2D(8, (3, 3), activation='relu')
encode_pool_layer_2 = MaxPooling2D((2, 2))
encode_conv_layer_3 = Conv2D(4, (3, 3), activation='relu')

encoded = encode_conv_layer_1(input_img)
encoded = encode_pool_layer_1(encoded)
encoded = encode_conv_layer_2(encoded)
encoded = encode_pool_layer_2(encoded)
encoded = encode_conv_layer_3(encoded)

# AutoEncoder 모델 구성 - Decoder 부분  -
decode_conv_layer_1 = Conv2DTranspose(4, (3, 3), activation='relu', padding='same')
decode_upsample_layer_1 = UpSampling2D((2, 2))
decode_conv_layer_2 = Conv2DTranspose(8, (3, 3), activation='relu', padding='same')
decode_upsample_layer_2 = UpSampling2D((2, 2))
decode_conv_layer_3 = Conv2DTranspose(16, (3, 3), activation='relu')
decode_upsample_layer_3 = UpSampling2D((2, 2))
decode_conv_layer_4 = Conv2DTranspose(1, (3, 3), activation='sigmoid', padding='same')

decoded = decode_conv_layer_1(encoded)   # Decoder는 Encoder의 출력을 입력으로 받습니다.
decoded = decode_upsample_layer_1(decoded)
decoded = decode_conv_layer_2(decoded)
decoded = decode_upsample_layer_2(decoded)
decoded = decode_conv_layer_3(decoded)
decoded = decode_upsample_layer_3(decoded)
decoded = decode_conv_layer_4(decoded)

# AutoEncoder 모델 정의
autoencoder = Model(input_img, decoded)
autoencoder.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 26, 26, 16)        160
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 13, 13, 16)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 11, 11, 8)         1160
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 5, 5, 8)           0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 3, 3, 4)           292
# _________________________________________________________________
# conv2d_transpose_12 (Conv2DT (None, 3, 3, 4)           148
# _________________________________________________________________
# up_sampling2d_15 (UpSampling (None, 6, 6, 4)           0
# _________________________________________________________________
# conv2d_transpose_13 (Conv2DT (None, 6, 6, 8)           296
# _________________________________________________________________
# up_sampling2d_16 (UpSampling (None, 12, 12, 8)         0
# _________________________________________________________________
# conv2d_transpose_14 (Conv2DT (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_17 (UpSampling (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_transpose_15 (Conv2DT (None, 28, 28, 1)         145
# =================================================================
# Total params: 3,369
# Trainable params: 3,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 4s 14ms/step - loss: 0.6985 - val_loss: 0.6975
# Epoch 2/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6971 - val_loss: 0.6961
# Epoch 3/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6957 - val_loss: 0.6948
# Epoch 4/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6944 - val_loss: 0.6935
# Epoch 5/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6931 - val_loss: 0.6921
# Epoch 6/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6918 - val_loss: 0.6907
# Epoch 7/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6902 - val_loss: 0.6890
# Epoch 8/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6884 - val_loss: 0.6869
# Epoch 9/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6862 - val_loss: 0.6844
# Epoch 10/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6836 - val_loss: 0.6815
# Epoch 11/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6806 - val_loss: 0.6783
# Epoch 12/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6774 - val_loss: 0.6749
# Epoch 13/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6738 - val_loss: 0.6710
# Epoch 14/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6699 - val_loss: 0.6667
# Epoch 15/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6654 - val_loss: 0.6619
# Epoch 16/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6604 - val_loss: 0.6565
# Epoch 17/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6547 - val_loss: 0.6503
# Epoch 18/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6484 - val_loss: 0.6435
# Epoch 19/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6414 - val_loss: 0.6359
# Epoch 20/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6335 - val_loss: 0.6275
# Epoch 21/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6249 - val_loss: 0.6182
# Epoch 22/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6153 - val_loss: 0.6081
# Epoch 23/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.6049 - val_loss: 0.5970
# Epoch 24/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5935 - val_loss: 0.5851
# Epoch 25/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5812 - val_loss: 0.5723
# Epoch 26/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5681 - val_loss: 0.5587
# Epoch 27/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5543 - val_loss: 0.5444
# Epoch 28/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5396 - val_loss: 0.5298
# Epoch 29/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5247 - val_loss: 0.5150
# Epoch 30/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.5101 - val_loss: 0.5006
# Epoch 31/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4956 - val_loss: 0.4871
# Epoch 32/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4822 - val_loss: 0.4749
# Epoch 33/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4701 - val_loss: 0.4645
# Epoch 34/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4602 - val_loss: 0.4560
# Epoch 35/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4521 - val_loss: 0.4495
# Epoch 36/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4456 - val_loss: 0.4445
# Epoch 37/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4411 - val_loss: 0.4409
# Epoch 38/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4375 - val_loss: 0.4381
# Epoch 39/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4348 - val_loss: 0.4360
# Epoch 40/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4328 - val_loss: 0.4342
# Epoch 41/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4308 - val_loss: 0.4327
# Epoch 42/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4292 - val_loss: 0.4314
# Epoch 43/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4278 - val_loss: 0.4302
# Epoch 44/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4266 - val_loss: 0.4291
# Epoch 45/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4254 - val_loss: 0.4281
# Epoch 46/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4241 - val_loss: 0.4271
# Epoch 47/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4233 - val_loss: 0.4261
# Epoch 48/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4225 - val_loss: 0.4251
# Epoch 49/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4214 - val_loss: 0.4242
# Epoch 50/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.4201 - val_loss: 0.4233

# %%
x_test_10 = x_test[:10]       # 테스트 데이터셋에서 10개만 골라서
x_test_hat = autoencoder.predict(x_test_10)    # AutoEncoder 모델의 이미지 복원생성
x_test_imgs = x_test_10.reshape(-1, 28, 28)
x_test_hat_imgs = x_test_hat.reshape(-1, 28, 28)

plt.figure(figsize=(12,5))  # 이미지 사이즈 지정
for i in range(10):
    # 원본이미지 출력
    plt.subplot(2, 10, i+1)
    plt.imshow(x_test_imgs[i])
    # 생성된 이미지 출력
    plt.subplot(2, 10, i+11)
    plt.imshow(x_test_hat_imgs[i])
